# %%
import pandas as pd

# %%
data = pd.read_csv(r'D:/python/datasain/food_delivery_datasets.csv')
print(data)
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 0     FOOD-10455               0  2018-08-12T20:35:08.001006         1800
# 1     FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 2     FOOD-10911               0  2018-09-19T18:08:09.387991         1418
# 3     FOOD-10932               0  2018-09-21T01:24:35.272499         1903
# 4     FOOD-10961               0  2018-09-22T17:57:45.523161         1716
# ...          ...             ...                         ...          ...
# 1071  FOOD-10921               0  2018-09-20T15:01:52.152828          900
# 1072  FOOD-10265            5000  2018-07-26T14:43:23.655294         1579
# 1073  FOOD-10534               0  2018-08-21T20:10:59.283185         2606
# 1074  FOOD-10158               0  2018-07-16T14:42:23.214427         2428
# 1075  FOOD-10770               0  2018-09-11T14:18:19.494258         1547
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
ongkir=data.groupby("delivery_fee")
ongkir["delivery_fee"].count()
# Out:
# delivery_fee
# 0         90
# 1000       9
# 2000      25
# 3000       6
# 4000     201
# 5000      41
# 6000      22
# 7000      38
# 8000      25
# 9000     182
# 10000     95
# 11000     40
# 12000     52
# 13000     57
# 14000     28
# 15000     22
# 16000     27
# 17000      9
# 18000     12
# 19000     11
# 20000     11
# 21000     16
# 22000     13
# 23000      4
# 24000      6
# 25000      8
# 28000      5
# 29000      4
# 30000      3
# 32000      1
# 33000      2
# 34000      1
# 35000      1
# 36000      2
# 37000      1
# 38000      1
# 39000      1
# 40000      1
# 43000      2
# 44000      1
# Name: delivery_fee, dtype: int64

# %%
ongkir_terbesar = data.groupby('delivery_fee').max()
print(ongkir_terbesar)
# Out:
#                 order_id  voucher_amount                   date_time  \
# delivery_fee
# 0             FOOD-11072           25000  2018-09-30T19:06:10.486158
# 1000          FOOD-10926           10000  2018-09-20T16:49:06.058154
# 2000          FOOD-11073           10000  2018-09-30T19:16:45.297306
# 3000          FOOD-10963            5000  2018-09-22T19:09:53.462836
# 4000          FOOD-11076            6000  2018-09-30T20:17:40.796955
# 5000          FOOD-11050           10000  2018-09-29T12:16:07.932616
# 6000          FOOD-11056            5000  2018-09-30T11:28:01.894626
# 7000          FOOD-11062            6000  2018-09-30T13:03:32.119740
# 8000          FOOD-11064            5000  2018-09-30T14:11:14.656405
# 9000          FOOD-11040            5000  2018-09-28T11:49:10.279427
# 10000         FOOD-11070            5000  2018-09-30T17:54:14.818659
# 11000         FOOD-11066            5000  2018-09-30T15:32:29.174246
# ...
